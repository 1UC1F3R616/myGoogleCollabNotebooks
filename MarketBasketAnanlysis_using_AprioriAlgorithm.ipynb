# %% [markdown]
# <a href="https://colab.research.google.com/github/1UC1F3R616/myGoogleCollabNotebooks/blob/master/MarketBasketAnanlysis_using_AprioriAlgorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd "/content/gdrive/My Drive/Kaggle"
#Check the present working directory using pwd command
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle datasets download -d vijayuv/onlineretail
# Out:
# ...
#  69% 5.00M/7.20M [00:00<00:00, 28.8MB/s]
# 100% 7.20M/7.20M [00:00<00:00, 35.2MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  onlineretail.zip
#   inflating: OnlineRetail.csv

# %%
ls
# Out:
# diabetes.csv  kaggle.json  OnlineRetail.csv

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df = pd.read_csv('OnlineRetail.csv', encoding = 'unicode_escape')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
# Removing rows which don't have invoice numbers and description
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [532621 rows x 8 columns]

# %%
# Visualizing data from France only
basket = (df[df['Country'] == 'France']
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
print(basket)
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# 580986                          0.0  ...                              0.0
# 581001                          0.0  ...                              0.0
# 581171                          0.0  ...                              0.0
# 581279                          0.0  ...                              0.0
# 581587                          0.0  ...                              0.0
#
# [392 rows x 1563 columns]

# %%
# Encode it and see
def encode_units(x):
  if x<=0:
    return 0
  if x>=1:
    return 1
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# 580986                            0  ...                                0
# 581001                            0  ...                                0
# 581171                            0  ...                                0
# 581279                            0  ...                                0
# 581587                            0  ...                                0
#
# [392 rows x 1562 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1)
rules.head()
# Out:
#                     antecedents  ... conviction
# 0   (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 1  (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 2    (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 3  (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 4    (ALARM CLOCK BAKELIKE RED)  ...   4.153061
#
# [5 rows x 9 columns]

# %%
rules[(rules['lift']>=6) &
      (rules['confidence']>=0.8)]
# Out:
#                                           antecedents  ... conviction
# 2                          (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 3                        (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 17                    (SET/6 RED SPOTTY PAPER PLATES)  ...   4.336735
# 18                      (SET/6 RED SPOTTY PAPER CUPS)  ...   7.852041
# 19                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...  34.897959
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...  ...   4.625850
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  34.489796
#
# [8 rows x 9 columns]
